# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('filter.txt', sep=" ", header=None)
data.columns = ['6','time', 'pos_n', 'pos_e', 'pos_d', 'q_x', 'q_y', 'q_z', 'q_w' , 'vel_n', 'vel_e', 'vel_d',  'w_n', 'w_e', 'w_d' , 'vdot_n', 'vdot_e' ,'vdot_d' , 'wdot_n', 'wdot_e', 'wdot_d',  'euler_roll', 'euler_pitch' ,'euler_yaw']

# %%
data.head
# Out:
# <bound method NDFrame.head of        6        time     pos_n     pos_e      pos_d       q_x       q_y  \
# 0      6   20.044981 -0.000050  0.000066   0.002693  0.006260 -0.030851
# 1      6   20.047210 -0.000050  0.000066   0.002693  0.006260 -0.030851
# 2      6   20.057082 -0.000065  0.000119   0.004920  0.006053 -0.030567
# 3      6   20.093877  0.000126  0.000449   0.022027  0.006029 -0.029918
# 4      6   20.097125  0.000144  0.000454   0.021984  0.006000 -0.029829
# ...   ..         ...       ...       ...        ...       ...       ...
# 19394  6  421.674892 -3.982739 -4.205174  10.860918  0.114850 -0.114978
# 19395  6  421.684741 -4.060940 -4.212707  10.908184  0.114776 -0.115855
# 19396  6  421.721104 -4.374517 -4.242003  11.093580  0.113761 -0.119062
# 19397  6  421.724749 -4.372560 -4.242072  11.093960  0.113743 -0.119082
# 19398  6  421.734866 -4.452807 -4.248539  11.139124  0.113356 -0.119797
#
#             q_z       q_w     vel_n  ...       w_d    vdot_n    vdot_e  \
# 0     -0.027471  0.999117 -0.002457  ... -0.004065  0.047700  0.015738
# 1     -0.027471  0.999117 -0.002457  ... -0.004065  0.047700  0.015738
# 2     -0.027540  0.999125 -0.001293  ... -0.005469  0.080438  0.060082
# 3     -0.027941  0.999134  0.010498  ... -0.007527  0.355429  0.323254
# 4     -0.027940  0.999136  0.011291  ... -0.007474  0.380996  0.340452
# ...         ...       ...       ...  ...       ...       ...       ...
# 19394  0.088260  0.982741 -8.340568  ... -0.070023  3.019028  2.878138
# 19395  0.088024  0.982668 -8.313572  ... -0.062610  2.735583  3.017739
# 19396  0.087339  0.982464 -8.216596  ... -0.051285  1.943376  3.359860
# 19397  0.087348  0.982462 -8.215736  ... -0.051025  1.932420  3.369254
# 19398  0.087218  0.982432 -8.195141  ... -0.048178  1.935132  3.366429
#
#          vdot_d    wdot_n    wdot_e    wdot_d  euler_roll  euler_pitch  \
# 0      8.646316 -0.108944 -0.397398 -0.096904    0.014232    -0.061342
# 1      8.646316 -0.108944 -0.397398 -0.096904    0.014232    -0.061342
# 2      8.720244 -0.216305 -0.273537 -0.119713    0.013805    -0.060785
# 3      7.323967 -0.315735  0.342320 -0.054246    0.013744    -0.059482
# 4      7.195777 -0.327779  0.363329 -0.053060    0.013682    -0.059305
# ...         ...       ...       ...       ...         ...          ...
# 19394 -2.968361 -2.366949  0.176039  0.501737    0.213592    -0.248820
# 19395 -3.015018 -2.610544  0.271126  0.598061    0.213410    -0.250512
# 19396 -2.957100 -1.135922  0.248698  0.277800    0.211168    -0.256626
# 19397 -2.930323 -1.167028  0.263588  0.284006    0.211128    -0.256667
# 19398 -2.886979 -1.218112  0.294193  0.281714    0.210294    -0.258010
#
#        euler_yaw
# 0      -0.055414
# 1      -0.055414
# 2      -0.055533
# 3      -0.056326
# 4      -0.056320
# ...          ...
# 19394   0.152328
# 19395   0.151702
# 19396   0.149983
# 19397   0.150002
# 19398   0.149710
#
# [19399 rows x 24 columns]>

# %%
data.plot(x="pos_e", y="pos_n");

# %%
data.time
# Out:
# 0         20.044981
# 1         20.047210
# 2         20.057082
# 3         20.093877
# 4         20.097125
#             ...
# 19394    421.674892
# 19395    421.684741
# 19396    421.721104
# 19397    421.724749
# 19398    421.734866
# Name: time, Length: 19399, dtype: float64

# %%
data['time'].describe()
# Out:
# count    19399.000000
# mean       220.829704
# std        115.983112
# min         20.044981
# 25%        120.559464
# 50%        220.932472
# 75%        321.237622
# max        421.734866
# Name: time, dtype: float64

# %%
d_filtes=data[data['time'] <100]

# %%
d_filtes=d_filtes[d_filtes['time']>60]

# %%
d_filtes.plot(x="pos_e", y="pos_n");

# %%
#Wybieram fragment od 70 do 100 w zakresie czasowym do modelowania

# %%
df=d_filtes
